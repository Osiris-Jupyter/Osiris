# %%
from IPython.display import Image
import random
a = random.randint(5,50)
a = 10
print(a)

# %%
b = 20
a = a+b
print(a)
# Out:
# 30

# %%
b += 10

# %%
a += b
print(a)
# Out:
# 120

# %%
Image('cat.jpg')
